# %% [markdown]
# # Data Wrangling¶
#
# ##### abdulaziz bin dayil

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import requests as rq
import os
from collections import Counter
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ###  Gathering

# %% [markdown]
# #### - `Twitter Archive`

# %%
twitter_archive_data = pd.read_csv('twitter-archive-enhanced.csv')
twitter_archive_data.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# #### - `image-predictions`

# %%
#Using the requests package download image predictions data
get_TSV = rq.get('https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv')
#Write image predictions data to a file in our folder
with open ('image-predictions.tsv','wb') as file:
    file.write(get_TSV.content)
    
image_data = pd.read_csv('image-predictions.tsv', sep='\t')

image_data.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# #### - Twitter Api

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = twitter_archive_data.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Fail
# 2: 892177421306343426
# Fail
# 3: 891815181378084864
# Fail
# 4: 891689557279858688
# Fail
# 5: 891327558926688256
# Fail
# 6: 891087950875897856
# Fail
# 7: 890971913173991426
# Fail
# 8: 890729181411237888
# Fail
# 9: 890609185150312448
# Fail
# 10: 890240255349198849
# Fail
# 11: 890006608113172480
# Fail
# 12: 889880896479866881
# Fail
# 13: 889665388333682689
# Fail
# 14: 889638837579907072
# Fail
# 15: 889531135344209921
# Fail
# 16: 889278841981685760
# Fail
# 17: 888917238123831296
# Fail
# 18: 888804989199671297
# Fail
# 19: 888554962724278272
# Fail
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Fail
# 22: 887705289381826560
# Fail
# 23: 887517139158093824
# Fail
# 24: 887473957103951883
# Fail
# 25: 887343217045368832
# Fail
# 26: 887101392804085760
# Fail
# 27: 886983233522544640
# Fail
# 28: 886736880519319552
# Fail
# 29: 886680336477933568
# Fail
# 30: 886366144734445568
# Fail
# 31: 886267009285017600
# Fail
# ...

# %%
tweet_data = pd.read_json('tweet-json.txt', lines=True, encoding='utf-8')
tweet_data.head()
# Out:
#                  created_at                  id              id_str  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
#
#                                            full_text  truncated  \
# 0  This is Phineas. He's a mystical boy. Only eve...      False
# 1  This is Tilly. She's just checking pup on you....      False
# 2  This is Archie. He is a rare Norwegian Pouncin...      False
# 3  This is Darla. She commenced a snooze mid meal...      False
# 4  This is Franklin. He would like you to stop ca...      False
#
#   display_text_range                                           entities  \
# 0            [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
dfs = [twitter_archive_data,
       image_data,
       tweet_data]

# %%
dfs_names = ["Twitter_Archive",
             "Image",
             "Tweets"]

# %% [markdown]
# ###  Data Wrangling

# %%
twitter_archive_data
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
image_data
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
tweet_data
# Out:
#                     created_at                  id              id_str  \
# 0    2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1    2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2    2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3    2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4    2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
# ...                        ...                 ...                 ...
# 2349 2015-11-16 00:24:50+00:00  666049248165822465  666049248165822464
# 2350 2015-11-16 00:04:52+00:00  666044226329800704  666044226329800704
# 2351 2015-11-15 23:21:54+00:00  666033412701032449  666033412701032448
# 2352 2015-11-15 23:05:30+00:00  666029285002620928  666029285002620928
# 2353 2015-11-15 22:32:08+00:00  666020888022790149  666020888022790144
#
#                                               full_text  truncated  \
# ...

# %%
twitter_archive_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
image_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   id                             2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
# ...

# %% [markdown]
# #### - `missing values`

# %%
def check_missing_data(data, df_name=''):
    print("Total Rows: \n", len(data))
    print("rows missing in the {0} data: \n".format(df_name), data.isnull().sum())
    print("\n\n")

# %%
for i, j in zip(dfs, dfs_names):
    check_missing_data(i, j)
# Out:
# Total Rows:
#  2356
# rows missing in the Twitter_Archive data:
#  tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64
#
#
#
# Total Rows:
#  2075
# rows missing in the Image data:
#  tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64
#
#
#
# ...

# %% [markdown]
# - The image data has zero missing data
# - Twitter archive and tweets data have many missing rows
# - some features in tweets data has all the rows missing

# %% [markdown]
# #### - `Checking the Data types`

# %%
def check_dtypes(data, name):
    print("Features of", name, "data: ")
    print(data.dtypes, "\n\n")

# %%
for i, j in zip(dfs, dfs_names):
    check_dtypes(i, j)
# Out:
# Features of Twitter_Archive data:
# tweet_id                        int64
# in_reply_to_status_id         float64
# in_reply_to_user_id           float64
# timestamp                      object
# source                         object
# text                           object
# retweeted_status_id           float64
# retweeted_status_user_id      float64
# retweeted_status_timestamp     object
# expanded_urls                  object
# rating_numerator                int64
# rating_denominator              int64
# name                           object
# doggo                          object
# floofer                        object
# pupper                         object
# puppo                          object
# dtype: object
#
#
# Features of Image data:
# tweet_id      int64
# jpg_url      object
# img_num       int64
# p1           object
# p1_conf     float64
# p1_dog         bool
# p2           object
# p2_conf     float64
# p2_dog         bool
# p3           object
# ...

# %% [markdown]
# - change the data type for timestamp from object to datetime

# %% [markdown]
#    ## Tidiness and quality

# %% [markdown]
# ###  - `Twitter Archive`

# %% [markdown]
# #### quality

# %% [markdown]
# - Convert timestamp to datetime dtype.
# - Replacing wrong(unappropriate) names with NONE
# - Extracting the source of tweet from the url's in source column
# - Drop columns with most of the NULL values

# %% [markdown]
# #### Tidiness

# %% [markdown]
# - Combining "doggo", "floofer", "pupper" and "puppo" columns into one column and then clean the text.
# - rating_numerator and rating_denominator Columns should be merged into one column named "Rating".

# %% [markdown]
# ###  - `Image`

# %% [markdown]
# #### quality

# %% [markdown]
# - In features p1, p2 and p3, there is underscore in between the names. Replacing it with space and then converting      text to camel case.
# - Extracting the names of Images from the image url.
# - Duplicates tweet ID for the url (https://pbs.twimg.com/media/C2kzTGxWEAEOpPL.jpg) with two tweet_id which are (822244816520155136) & (823269594223824897)
# - (https://pbs.twimg.com/media/CsrjryzWgAAZY00.jpg) with two tweet_id which are (777684233540206592) & (802624713319034886) which should be dropped.¶

# %% [markdown]
# #### Tidiness

# %% [markdown]
# ###  - `Tweets `

# %% [markdown]
# #### quality

# %% [markdown]
# - Dropping non-useful columns with all NULL values
# - Rename id column to tweet_id, as it is the primary key in data and will be used later for merging the dataframes.

# %% [markdown]
# #### Tidiness

# %% [markdown]
# - Should merge all the three dataframes into one dataframe.

# %% [markdown]
# ## Clean

# %% [markdown]
# ####  - `Twitter Archive`

# %%
#make a copy of original df
twitter_archive_clean = dfs[0].copy()

# %% [markdown]
# #### Define

# %% [markdown]
# - Convert timestamp to datetime dtype.

# %% [markdown]
# #### Code

# %%
twitter_archive_clean['timestamp'] = \
pd.to_datetime(twitter_archive_clean['timestamp'])

# %% [markdown]
# #### test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   datetime64[ns, UTC]
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
twitter_archive_clean['timestamp'].head()
# Out:
# 0   2017-08-01 16:23:56+00:00
# 1   2017-08-01 00:17:27+00:00
# 2   2017-07-31 00:18:03+00:00
# 3   2017-07-30 15:58:51+00:00
# 4   2017-07-29 16:00:24+00:00
# Name: timestamp, dtype: datetime64[ns, UTC]

# %% [markdown]
# #### Define

# %% [markdown]
# - Combining "doggo", "floofer", "pupper" and "puppo" columns into one column and then clean the text.

# %% [markdown]
# #### Code

# %%
# Merge the four columns ("doggo", "floofer", "pupper", "puppo")to one column("dog_stage")
twitter_archive_clean['dog_stage'] = twitter_archive_clean[['doggo', 'floofer', 
                                                                      'pupper', 
                        'puppo']].apply(lambda x: ' - '.join(x.dropna().astype(str)), axis=1)

twitter_archive_clean['dog_stage'] = \
twitter_archive_clean['dog_stage'].map(lambda x: x.lstrip('None -').rstrip(''))
twitter_archive_clean['dog_stage'].head()
# Out:
# 0
# 1
# 2
# 3
# 4
# Name: dog_stage, dtype: object

# %%
twitter_archive_clean['dog_stage'].value_counts()
# Out:
#                                  1976
# pupper - None                     245
# doggo - None - None - None         83
# puppo                              29
# doggo - None - pupper - None       12
# floofer - None - None               9
# doggo - floofer - None - None       1
# doggo - None - None - puppo         1
# Name: dog_stage, dtype: int64

# %%
twitter_archive_clean['dog_stage'].unique().tolist()
# Out:
# ['',
#  'doggo - None - None - None',
#  'puppo',
#  'pupper - None',
#  'floofer - None - None',
#  'doggo - None - None - puppo',
#  'doggo - floofer - None - None',
#  'doggo - None - pupper - None']

# %%
map_stages = {'': "None",
             'doggo - None - None - None' : "doggo",
             'puppo' : "puppo",
             'pupper - None':"pupper",
             'floofer - None - None': "floofer",
             'doggo - None - None - puppo': "pupper, puppo",
             'doggo - floofer - None - None': "doggo, floofer",
             'doggo - None - pupper - None': "doggo, pupper"}

# %%
twitter_archive_clean['dog_stage'].replace(map_stages, inplace=True)

# %%
twitter_archive_clean['dog_stage'].unique().tolist()
# Out:
# ['None',
#  'doggo',
#  'puppo',
#  'pupper',
#  'floofer',
#  'pupper, puppo',
#  'doggo, floofer',
#  'doggo, pupper']

# %% [markdown]
# Combining the dog-stages columns to a single column names as dog_stage

# %% [markdown]
# #### test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   datetime64[ns, UTC]
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
twitter_archive_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
# 2 2017-07-31 00:18:03+00:00
# 3 2017-07-30 15:58:51+00:00
# 4 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# #### Define

# %% [markdown]
# - Replacing wrong(unappropriate) names with NONE

# %% [markdown]
# #### Code

# %%
map_names = {"the": 'None', 
 "light": 'None',
 "life": 'None', 
 "an": 'None', 
 "a": 'None', 
 "by": 'None', 
 "actually": 'None', 
 "just": 'None', 
 "getting": 'None', 
 "infuriating": 'None',
"old": 'None', 
 "all": 'None', 
 "this": 'None', 
 "very": 'None', 
 "mad": 'None', 
 "not": 'None', 
 "one": 'None', 
 "my": 'None', 
 "quite": 'None', 
 "such": 'None'}

# %%
twitter_archive_clean['name'].replace(map_names, inplace=True)

# %% [markdown]
# #### test

# %%
twitter_archive_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
# 2 2017-07-31 00:18:03+00:00
# 3 2017-07-30 15:58:51+00:00
# 4 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# #### Define

# %% [markdown]
# - Extracting the source of tweet from the url's in source column

# %% [markdown]
# #### Code

# %%
import re
twitter_archive_clean['source'] = \
twitter_archive_clean['source'].apply(lambda x: re.findall(">(.*)<", x)[0]).str.strip()

# %% [markdown]
# #### test

# %%
twitter_archive_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp              source  \
# 0 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 2 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 3 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 4 2017-07-29 16:00:24+00:00  Twitter for iPhone
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# ...

# %% [markdown]
# #### Define

# %% [markdown]
# - Drop columns with NULL values

# %% [markdown]
# #### Code

# %%
columns_with_NULL_df1 = ['retweeted_status_user_id',
                   'retweeted_status_id',
                   'retweeted_status_timestamp',
                   'in_reply_to_status_id',
                   'in_reply_to_user_id',
                   'in_reply_to_status_id',
                   'expanded_urls',
                   'doggo',
                   'floofer',
                   'pupper',
                   'puppo']

# %%
twitter_archive_clean.drop(columns_with_NULL_df1, axis=1, inplace=True)

# %% [markdown]
# #### test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   datetime64[ns, UTC]
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   rating_numerator    2356 non-null   int64
#  5   rating_denominator  2356 non-null   int64
#  6   name                2356 non-null   object
#  7   dog_stage           2356 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(4)
# memory usage: 147.4+ KB

# %% [markdown]
# #### Define

# %% [markdown]
# - rating_numerator and rating_denominator Columns should be merged into one column named "Rating".

# %% [markdown]
# #### Code

# %%
twitter_archive_clean['Dog_Rate'] = twitter_archive_clean.rating_numerator / twitter_archive_clean.rating_denominator

# %%
twitter_archive_clean.drop(['rating_numerator','rating_denominator'], axis=1, inplace = True)

# %% [markdown]
# #### test

# %%
twitter_archive_clean
# Out:
#                 tweet_id                 timestamp              source  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1     892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 2     891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 3     891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 4     891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
# ...                  ...                       ...                 ...
# 2351  666049248165822465 2015-11-16 00:24:50+00:00  Twitter for iPhone
# 2352  666044226329800704 2015-11-16 00:04:52+00:00  Twitter for iPhone
# 2353  666033412701032449 2015-11-15 23:21:54+00:00  Twitter for iPhone
# 2354  666029285002620928 2015-11-15 23:05:30+00:00  Twitter for iPhone
# 2355  666020888022790149 2015-11-15 22:32:08+00:00  Twitter for iPhone
#
#                                                    text      name dog_stage  \
# ...

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   2356 non-null   int64
#  1   timestamp  2356 non-null   datetime64[ns, UTC]
#  2   source     2356 non-null   object
#  3   text       2356 non-null   object
#  4   name       2356 non-null   object
#  5   dog_stage  2356 non-null   object
#  6   Dog_Rate   2356 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(1), object(4)
# memory usage: 129.0+ KB

# %% [markdown]
# ####  - `Image`

# %%
#make a copy of original df
image_clean = dfs[1].copy()

# %%
image_clean
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %% [markdown]
# #### Define

# %% [markdown]
# - In features p1, p2 and p3, there is underscore in between the names. Replacing it with space and then converting      text to camel case.

# %% [markdown]
# #### Code

# %%
for i in ['p1', 'p2', 'p3']:
    #replacing _ with " "
    image_clean[i] = image_clean[i].str.replace('_', ' ')
    #converting to camel case
    image_clean[i] = image_clean[i].str.title()

# %% [markdown]
# #### test

# %%
image_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh Springer Spaniel  0.465074    True              Collie
# 1        1                 Redbone  0.506826    True  Miniature Pinscher
# 2        1         German Shepherd  0.596461    True            Malinois
# 3        1     Rhodesian Ridgeback  0.408143    True             Redbone
# 4        1      Miniature Pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# #### Define

# %% [markdown]
# - Extracting the names of Images from the image url.

# %% [markdown]
# #### Code

# %%
image_clean['jpg_file_name'] = \
image_clean['jpg_url'].apply(lambda x: re.findall("/.*/(.*)", x)[0])

# %% [markdown]
# #### test

# %%
image_clean.query('jpg_url == "https://pbs.twimg.com/media/C2kzTGxWEAEOpPL.jpg"')
# Out:
#                 tweet_id                                          jpg_url  \
# 1738  822244816520155136  https://pbs.twimg.com/media/C2kzTGxWEAEOpPL.jpg
# 1746  823269594223824897  https://pbs.twimg.com/media/C2kzTGxWEAEOpPL.jpg
#
#       img_num       p1   p1_conf  p1_dog          p2   p2_conf  p2_dog  \
# 1738        1  Samoyed  0.585441    True  Pomeranian  0.193654    True
# 1746        1  Samoyed  0.585441    True  Pomeranian  0.193654    True
#
#               p3   p3_conf  p3_dog        jpg_file_name
# 1738  Arctic Fox  0.071648   False  C2kzTGxWEAEOpPL.jpg
# 1746  Arctic Fox  0.071648   False  C2kzTGxWEAEOpPL.jpg

# %% [markdown]
# #### Define

# %% [markdown]
#  dropd the Duplicates tweet ID for the url

# %% [markdown]
# #### Code

# %%
image_clean = image_clean[image_clean['tweet_id'] != 822244816520155136]

# %% [markdown]
# #### test

# %%
image_clean[image_clean['tweet_id'] == 822244816520155136]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog, jpg_file_name]
# Index: []

# %% [markdown]
# #### Define

# %% [markdown]
# - droppe one from them (https://pbs.twimg.com/media/CsrjryzWgAAZY00.jpg) with two tweet_id which are (777684233540206592) &(802624713319034886)

# %% [markdown]
# #### Code

# %%
image_clean.query('jpg_url == "https://pbs.twimg.com/media/CsrjryzWgAAZY00.jpg"')
# Out:
#                 tweet_id                                          jpg_url  \
# 1457  777684233540206592  https://pbs.twimg.com/media/CsrjryzWgAAZY00.jpg
# 1619  802624713319034886  https://pbs.twimg.com/media/CsrjryzWgAAZY00.jpg
#
#       img_num              p1   p1_conf  p1_dog                p2  p2_conf  \
# 1457        1  Cocker Spaniel  0.253442    True  Golden Retriever  0.16285
# 1619        1  Cocker Spaniel  0.253442    True  Golden Retriever  0.16285
#
#       p2_dog          p3   p3_conf  p3_dog        jpg_file_name
# 1457    True  Otterhound  0.110921    True  CsrjryzWgAAZY00.jpg
# 1619    True  Otterhound  0.110921    True  CsrjryzWgAAZY00.jpg

# %%
image_clean = image_clean[image_clean['tweet_id'] != 777684233540206592]

# %% [markdown]
# ### test

# %%
image_clean.query('jpg_url == "https://pbs.twimg.com/media/CsrjryzWgAAZY00.jpg"')
# Out:
#                 tweet_id                                          jpg_url  \
# 1619  802624713319034886  https://pbs.twimg.com/media/CsrjryzWgAAZY00.jpg
#
#       img_num              p1   p1_conf  p1_dog                p2  p2_conf  \
# 1619        1  Cocker Spaniel  0.253442    True  Golden Retriever  0.16285
#
#       p2_dog          p3   p3_conf  p3_dog        jpg_file_name
# 1619    True  Otterhound  0.110921    True  CsrjryzWgAAZY00.jpg

# %%
image_clean
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %% [markdown]
# ####  - `Tweets `

# %%
#make a copy of original df
tweet_clean = dfs[2].copy()

# %% [markdown]
# #### Define

# %% [markdown]
# - Rename id column to tweet_id, as it is the primary key in data and will be used later for merging the dataframes.

# %% [markdown]
# #### Code

# %%
tweet_clean.rename(columns={'id': 'tweet_id'}, inplace=True)

# %% [markdown]
# #### test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   tweet_id                       2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
# ...

# %% [markdown]
# #### Define

# %% [markdown]
# - Dropping non-useful columns with all NULL values

# %% [markdown]
# #### Code

# %%
Dropping_non_useful_columns = ['contributors',
                  'display_text_range',
                  'created_at',
                 'coordinates',
                 'entities',
                 'extended_entities',
                 'favorited',
                 'geo',
                 'id_str',
                 'in_reply_to_screen_name',
                 'in_reply_to_status_id',
                 'in_reply_to_status_id_str',
                 'in_reply_to_user_id',
                 'in_reply_to_user_id_str',
                 'is_quote_status',
                 'place',
                 'possibly_sensitive',
                 'possibly_sensitive_appealable',
                 'quoted_status',
                 'quoted_status_id',
                 'quoted_status_id_str',
                 'retweeted',
                 'retweeted_status',
                 'source',
                 'truncated',
                 'user']

# %%
tweet_clean.drop(Dropping_non_useful_columns, axis=1, inplace=True)

# %% [markdown]
# #### test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   full_text       2354 non-null   object
#  2   retweet_count   2354 non-null   int64
#  3   favorite_count  2354 non-null   int64
#  4   lang            2354 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 92.1+ KB

# %%
tweet_clean
# Out:
#                 tweet_id                                          full_text  \
# 0     892420643555336193  This is Phineas. He's a mystical boy. Only eve...
# 1     892177421306343426  This is Tilly. She's just checking pup on you....
# 2     891815181378084864  This is Archie. He is a rare Norwegian Pouncin...
# 3     891689557279858688  This is Darla. She commenced a snooze mid meal...
# 4     891327558926688256  This is Franklin. He would like you to stop ca...
# ...                  ...                                                ...
# 2349  666049248165822465  Here we have a 1949 1st generation vulpix. Enj...
# 2350  666044226329800704  This is a purebred Piers Morgan. Loves to Netf...
# 2351  666033412701032449  Here is a very happy pup. Big fan of well-main...
# 2352  666029285002620928  This is a western brown Mitsubishi terrier. Up...
# 2353  666020888022790149  Here we have a Japanese Irish Setter. Lost eye...
#
#       retweet_count  favorite_count lang
# ...

# %%
cleaned_dfs = [twitter_archive_clean,
               image_clean,
               tweet_clean]

# %% [markdown]
# ###  test for missing data

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   2356 non-null   int64
#  1   timestamp  2356 non-null   datetime64[ns, UTC]
#  2   source     2356 non-null   object
#  3   text       2356 non-null   object
#  4   name       2356 non-null   object
#  5   dog_stage  2356 non-null   object
#  6   Dog_Rate   2356 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(1), object(4)
# memory usage: 129.0+ KB

# %%
for i, j in zip(cleaned_dfs, dfs_names):
    check_missing_data(i, j)
# Out:
# Total Rows:
#  2356
# rows missing in the Twitter_Archive data:
#  tweet_id     0
# timestamp    0
# source       0
# text         0
# name         0
# dog_stage    0
# Dog_Rate     0
# dtype: int64
#
#
#
# Total Rows:
#  2073
# rows missing in the Image data:
#  tweet_id         0
# jpg_url          0
# img_num          0
# p1               0
# p1_conf          0
# p1_dog           0
# p2               0
# p2_conf          0
# p2_dog           0
# p3               0
# p3_conf          0
# p3_dog           0
# jpg_file_name    0
# dtype: int64
#
#
#
# Total Rows:
#  2354
# rows missing in the Tweets data:
#  tweet_id          0
# full_text         0
# retweet_count     0
# favorite_count    0
# lang              0
# dtype: int64

# %% [markdown]
# ###  Merging the cleaned data

# %%
#  Merging the cleaned data
cleaned_master = pd.merge(cleaned_dfs[0], cleaned_dfs[1], on='tweet_id', how='inner')
cleaned_master = pd.merge(cleaned_master, cleaned_dfs[2], on='tweet_id', how='inner')

# %%
check_missing_data(cleaned_master, "Master")
# Out:
# Total Rows:
#  2071
# rows missing in the Master data:
#  tweet_id          0
# timestamp         0
# source            0
# text              0
# name              0
# dog_stage         0
# Dog_Rate          0
# jpg_url           0
# img_num           0
# p1                0
# p1_conf           0
# p1_dog            0
# p2                0
# p2_conf           0
# p2_dog            0
# p3                0
# p3_conf           0
# p3_dog            0
# jpg_file_name     0
# full_text         0
# retweet_count     0
# favorite_count    0
# lang              0
# dtype: int64

# %% [markdown]
# ### storing the cleaned data into csv files

# %%
cleaned_folder = 'Cleaned Data'

# %%
if not os.path.exists(cleaned_folder):
    os.mkdir(cleaned_folder)

# %%
twitter_archive_clean.to_csv(os.path.join(cleaned_folder, 
                                               'twitter_archive_data_clean.csv'), header=True)

image_clean.to_csv(os.path.join(cleaned_folder,
                                 'image_data_clean.csv'), header=True)

tweet_clean.to_csv(os.path.join(cleaned_folder,
                                   'tweet_data_clean.csv'), header=True)

cleaned_master.to_csv(os.path.join(cleaned_folder,
                         'twitter_archive_master.csv'), header=True)

# %% [markdown]
# Data Wrangling End

# %%
cleaned_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2071 entries, 0 to 2070
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2071 non-null   int64
#  1   timestamp       2071 non-null   datetime64[ns, UTC]
#  2   source          2071 non-null   object
#  3   text            2071 non-null   object
#  4   name            2071 non-null   object
#  5   dog_stage       2071 non-null   object
#  6   Dog_Rate        2071 non-null   float64
#  7   jpg_url         2071 non-null   object
#  8   img_num         2071 non-null   int64
#  9   p1              2071 non-null   object
#  10  p1_conf         2071 non-null   float64
#  11  p1_dog          2071 non-null   bool
#  12  p2              2071 non-null   object
#  13  p2_conf         2071 non-null   float64
#  14  p2_dog          2071 non-null   bool
#  15  p3              2071 non-null   object
#  16  p3_conf         2071 non-null   float64
# ...

# %%
cleaned_master.describe()
# Out:
#            tweet_id     Dog_Rate      img_num      p1_conf       p2_conf  \
# count  2.071000e+03  2071.000000  2071.000000  2071.000000  2.071000e+03
# mean   7.383039e+17     1.170006     1.203766     0.594701  1.346244e-01
# std    6.780333e+16     3.990806     0.562092     0.271262  1.007214e-01
# min    6.660209e+17     0.000000     1.000000     0.044333  1.011300e-08
# 25%    6.764553e+17     1.000000     1.000000     0.364412  5.388625e-02
# 50%    7.117438e+17     1.100000     1.000000     0.589011  1.181810e-01
# 75%    7.931884e+17     1.200000     1.000000     0.844583  1.957615e-01
# max    8.924206e+17   177.600000     4.000000     1.000000  4.880140e-01
#
#             p3_conf  retweet_count  favorite_count
# count  2.071000e+03    2071.000000     2071.000000
# mean   6.031016e-02    2971.805408     8540.186866
# std    5.093954e-02    5053.921060    12085.854901
# min    1.740170e-10      16.000000        0.000000
# 25%    1.619495e-02     634.000000     1673.000000
# ...

# %% [markdown]
# ### -Analysis

# %%
breeds_data = pd.DataFrame(Counter(cleaned_master['p1']).most_common(20), 
                         columns=['Breed', 'Count'])

# %% [markdown]
# #### Q1: what are the most Dog Stages

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x='dog_stage', 
              data=cleaned_master[cleaned_master['dog_stage'] != 'None'], palette='rainbow')
plt.xlabel('Dog Stage', labelpad=20, fontsize=22)
plt.ylabel('Count', labelpad=20, fontsize=22)
plt.title("Counts of Dog Stages", fontsize=25)
plt.show()

# %% [markdown]
# #### Q2: The Statics of source tweets

# %%
tweets_source = twitter_archive_clean.source.value_counts()
tweets_source.plot(kind = 'bar');
plt.xlabel('Source of twitter application');
plt.ylabel('Number of tweets');
plt.title('The number of source tweets');

# %% [markdown]
# #### Q3:whats are the Top 30 doggo names

# %%
plt.style.use('fivethirtyeight')

# %%
top_30_names_doggo = pd.DataFrame(Counter(cleaned_master.name).most_common(30)[1:])

plt.figure(figsize=(20, 10))
sns.barplot(0, 1, data=top_30_names_doggo, color="#005682")
plt.ylabel("Total counts", labelpad=20)
plt.xlabel("Names", labelpad=20)
plt.title("Top 30 doggo names", fontsize=25)
plt.xticks(rotation=90)
plt.show()
# Out:
# /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Q4:What are the most popular dog breeds

# %%
plt.figure(figsize=(20, 10))
sns.barplot('Breed', 'Count', data=breeds_data, color="red")
plt.ylabel("Total counts", labelpad=20)
plt.xlabel("Breeds", labelpad=20)
plt.title("Top 20 dog breeds", fontsize=25)
plt.xticks(rotation=90)
plt.show()
# Out:
# /Users/abdulazizbindayil/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
